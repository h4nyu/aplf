# %%
from aplf.kaggle.tgs import graph
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
train_progress_df = pd.read_json('/store/kaggle/tgs/output/progress.json')
print(train_progress_df.info())
plt.scatter(x=train_progress_df.index, y=train_progress_df['train'])
plt.scatter(x=train_progress_df.index, y=train_progress_df['val'])
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 584 entries, 0 to 99
# Data columns (total 2 columns):
# train    584 non-null float64
# val      584 non-null float64
# dtypes: float64(2)
# memory usage: 13.7 KB
# None
